# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Install CSV file

# %%
df = pd.read_csv("Most Visited Amusement Theme Parks Worldwide 2000-2019.csv",)

df.head()
# Out:
#                      Event Country  \
# 0            Magic Kingdom     USA
# 1               Disneyland     USA
# 2                    Epcot     USA
# 3       Disney-MGM Studios     USA
# 4  Disney's Animal Kingdom     USA
#
#                                                Image      2000      2001  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...  15400000  14700000
# 1  https://upload.wikimedia.org/wikipedia/en/thum...  13900000  12300000
# 2  https://upload.wikimedia.org/wikipedia/en/thum...  10600000   9000000
# 3  https://upload.wikimedia.org/wikipedia/en/thum...   8900000   8300000
# 4  https://upload.wikimedia.org/wikipedia/en/thum...   8300000   7700000
#
#        2002      2003      2004      2005      2006  ...  Unnamed: 69  \
# 0  14000000  14040000  15100000  16100000  16640000  ...          NaN
# 1  12700000  12720000  13400000  14500000  14730000  ...          NaN
# 2   8300000   8620000   9400000   9900000  10460000  ...          NaN
# ...

# %% [markdown]
# ### Identify nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 79 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Event        17 non-null     object
#  1   Country      17 non-null     object
#  2   Image        17 non-null     object
#  3   2000         17 non-null     int64
#  4   2001         17 non-null     int64
#  5   2002         17 non-null     int64
#  6   2003         17 non-null     int64
#  7   2004         17 non-null     int64
#  8   2005         17 non-null     int64
#  9   2006         17 non-null     int64
#  10  2007         17 non-null     int64
#  11  2008         17 non-null     int64
#  12  2009         17 non-null     int64
#  13  2010         17 non-null     int64
#  14  2011         17 non-null     int64
#  15  2012         17 non-null     int64
#  16  2013         17 non-null     int64
#  17  2014         17 non-null     int64
#  18  2015         17 non-null     int64
# ...

# %% [markdown]
# ### Checking for  Duplicates

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Event, Country, Image, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2000-2019, Unnamed: 24, Unnamed: 25, Unnamed: 26, Unnamed: 27, Unnamed: 28, Unnamed: 29, Unnamed: 30, Unnamed: 31, Unnamed: 32, Unnamed: 33, Unnamed: 34, Unnamed: 35, Unnamed: 36, Unnamed: 37, Unnamed: 38, Unnamed: 39, Unnamed: 40, Unnamed: 41, Unnamed: 42, Unnamed: 43, Unnamed: 44, Unnamed: 45, Unnamed: 46, Unnamed: 47, Unnamed: 48, Unnamed: 49, Unnamed: 50, Unnamed: 51, Unnamed: 52, Unnamed: 53, Unnamed: 54, Unnamed: 55, Unnamed: 56, Unnamed: 57, Unnamed: 58, Unnamed: 59, Unnamed: 60, Unnamed: 61, Unnamed: 62, Unnamed: 63, Unnamed: 64, Unnamed: 65, Unnamed: 66, Unnamed: 67, Unnamed: 68, Unnamed: 69, Unnamed: 70, Unnamed: 71, Unnamed: 72, Unnamed: 73, Unnamed: 74, Unnamed: 75, Unnamed: 76, Unnamed: 77, Unnamed: 78]
# Index: []
#
# [0 rows x 79 columns]

# %% [markdown]
# ### Removing Columns

# %%
drp_col_df = df.drop(["Image", "Unnamed: 24", "Unnamed: 25", "Unnamed: 26", "Unnamed: 27", "Unnamed: 28", "Unnamed: 29", 
                      "Unnamed: 30", "Unnamed: 31", "Unnamed: 32", "Unnamed: 33", "Unnamed: 34", "Unnamed: 35", "Unnamed: 36", "Unnamed: 37", "Unnamed: 38", "Unnamed: 39", 
                      "Unnamed: 40", "Unnamed: 41", "Unnamed: 42", "Unnamed: 43", "Unnamed: 44", "Unnamed: 45", "Unnamed: 46", "Unnamed: 47", "Unnamed: 48", "Unnamed: 49", 
                      "Unnamed: 50", "Unnamed: 51", "Unnamed: 52", "Unnamed: 53", "Unnamed: 54", "Unnamed: 55", "Unnamed: 56", "Unnamed: 57", "Unnamed: 58", "Unnamed: 59", 
                      "Unnamed: 60", "Unnamed: 61", "Unnamed: 62", "Unnamed: 63", "Unnamed: 64", "Unnamed: 65", "Unnamed: 66", "Unnamed: 67", "Unnamed: 68", "Unnamed: 69", 
                      "Unnamed: 70", "Unnamed: 71", "Unnamed: 72", "Unnamed: 73", "Unnamed: 74", "Unnamed: 75", "Unnamed: 76", "Unnamed: 77", "Unnamed: 78"], axis=1)
drp_col_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Event      17 non-null     object
#  1   Country    17 non-null     object
#  2   2000       17 non-null     int64
#  3   2001       17 non-null     int64
#  4   2002       17 non-null     int64
#  5   2003       17 non-null     int64
#  6   2004       17 non-null     int64
#  7   2005       17 non-null     int64
#  8   2006       17 non-null     int64
#  9   2007       17 non-null     int64
#  10  2008       17 non-null     int64
#  11  2009       17 non-null     int64
#  12  2010       17 non-null     int64
#  13  2011       17 non-null     int64
#  14  2012       17 non-null     int64
#  15  2013       17 non-null     int64
#  16  2014       17 non-null     int64
#  17  2015       17 non-null     int64
#  18  2016       17 non-null     int64
#  19  2017       17 non-null     int64
# ...

# %%
drp_col_df.head()
# Out:
#                      Event Country      2000      2001      2002      2003  \
# 0            Magic Kingdom     USA  15400000  14700000  14000000  14040000
# 1               Disneyland     USA  13900000  12300000  12700000  12720000
# 2                    Epcot     USA  10600000   9000000   8300000   8620000
# 3       Disney-MGM Studios     USA   8900000   8300000   8000000   7870000
# 4  Disney's Animal Kingdom     USA   8300000   7700000   7300000   7300000
#
#        2004      2005      2006      2007  ...      2011      2012      2013  \
# 0  15100000  16100000  16640000  17060000  ...  17140000  17540000  18580000
# 1  13400000  14500000  14730000  14870000  ...  16140000  15960000  16200000
# 2   9400000   9900000  10460000  10900000  ...  10830000  11060000  11230000
# 3   8200000   8600000   9100000   9510000  ...   9690000   9910000  10110000
# 4   7800000   8200000   8900000   9490000  ...   9780000   9990000  10190000
#
# ...

# %% [markdown]
# ### Exporting to CSV file

# %%
drp_col_df.to_csv("most_visited_amusement.csv", encoding="utf-8")
